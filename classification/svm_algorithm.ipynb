# %% [markdown]
# # SVM Algorithm #

# %% [markdown]
# SVM Algorithm implementation on dataset for classification problem

# %% [markdown]
# # Importing Libraries #

# %% [markdown]
# Importing the required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"c_mutlu.csv")
data
# Out:
#      Mutluluk  Fomo  Nevrotik  Disdon  Acikfikir  Yumbas  Durust  Mobba  Oyba  \
# 0        2.48  3.05       4.4     1.2        4.0     3.2     2.2   3.03  4.67
# 1        3.86  2.82       3.4     5.0        5.0     3.8     4.2   2.58  1.22
# 2        3.29  1.50       3.4     3.6        3.2     4.0     3.8   1.21  0.00
# 3        3.82  3.23       1.6     5.0        4.6     4.6     4.6   4.30  0.00
# 4        3.77  2.86       2.0     4.0        5.0     3.0     3.8   2.00  1.78
# ..        ...   ...       ...     ...        ...     ...     ...    ...   ...
# 492      3.24  4.36       3.4     2.6        1.2     1.8     1.2   3.88  0.00
# 493      2.52  3.95       4.2     2.6        3.8     4.2     4.0   2.33  0.00
# 494      4.34  2.59       2.6     2.6        4.8     3.6     3.8   1.30  2.33
# 495      3.66  1.41       3.2     3.2        4.8     3.0     1.6   1.64  2.67
# 496      3.62  2.91       1.8     2.6        5.0     5.0     5.0   1.73  1.78
#
#      Sosvirtol  Sosvirco  Sosvirpro  Sosvirinfo  Target
# 0          3.0      3.00       3.22        3.50       0
# 1          3.2      2.78       1.89        3.50       1
# 2          1.8      1.33       1.00        1.83       1
# 3          5.0      4.67       4.00        3.67       1
# 4          2.2      2.44       2.56        2.33       1
# ..         ...       ...        ...         ...     ...
# 492        4.6      3.78       3.56        4.33       1
# 493        4.0      1.11       1.44        3.67       1
# 494        1.8      2.33       1.78        3.50       1
# 495        3.2      2.11       2.56        2.83       1
# 496        2.0      1.56       1.56        1.50       1
#
# [497 rows x 14 columns]

# %% [markdown]
# Modify the dataset for classification problem The output/target class is set 'Mutluluk' column

# %%
data_mutlu = data.drop(['Mutluluk'], axis=1)
data_mutlu
# Out:
#      Fomo  Nevrotik  Disdon  Acikfikir  Yumbas  Durust  Mobba  Oyba  \
# 0    3.05       4.4     1.2        4.0     3.2     2.2   3.03  4.67
# 1    2.82       3.4     5.0        5.0     3.8     4.2   2.58  1.22
# 2    1.50       3.4     3.6        3.2     4.0     3.8   1.21  0.00
# 3    3.23       1.6     5.0        4.6     4.6     4.6   4.30  0.00
# 4    2.86       2.0     4.0        5.0     3.0     3.8   2.00  1.78
# ..    ...       ...     ...        ...     ...     ...    ...   ...
# 492  4.36       3.4     2.6        1.2     1.8     1.2   3.88  0.00
# 493  3.95       4.2     2.6        3.8     4.2     4.0   2.33  0.00
# 494  2.59       2.6     2.6        4.8     3.6     3.8   1.30  2.33
# 495  1.41       3.2     3.2        4.8     3.0     1.6   1.64  2.67
# 496  2.91       1.8     2.6        5.0     5.0     5.0   1.73  1.78
#
#      Sosvirtol  Sosvirco  Sosvirpro  Sosvirinfo  Target
# 0          3.0      3.00       3.22        3.50       0
# 1          3.2      2.78       1.89        3.50       1
# 2          1.8      1.33       1.00        1.83       1
# 3          5.0      4.67       4.00        3.67       1
# 4          2.2      2.44       2.56        2.33       1
# ..         ...       ...        ...         ...     ...
# 492        4.6      3.78       3.56        4.33       1
# 493        4.0      1.11       1.44        3.67       1
# 494        1.8      2.33       1.78        3.50       1
# 495        3.2      2.11       2.56        2.83       1
# 496        2.0      1.56       1.56        1.50       1
#
# [497 rows x 13 columns]

# %%
data_mutlu['Target'].value_counts()
# Out:
# 1    459
# 0     38
# Name: Target, dtype: int64

# %%
X = data_mutlu.drop(["Target"], axis=1)
y = data_mutlu["Target"]

# %% [markdown]
# # Oversampling method for unbalanced dataset #

# %% [markdown]
# Importing the imblearn library for oversampling method

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\atilla\appdata\local\programs\python\python38\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\atilla\appdata\local\programs\python\python38\lib\site-packages (from imblearn) (0.8.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\atilla\appdata\local\programs\python\python38\lib\site-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\atilla\appdata\local\programs\python\python38\lib\site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\atilla\appdata\local\programs\python\python38\lib\site-packages (from imbalanced-learn->imblearn) (1.20.1)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\atilla\appdata\local\programs\python\python38\lib\site-packages (from imbalanced-learn->imblearn) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\atilla\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# WARNING: You are using pip version 21.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\users\atilla\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='minority', random_state=42)
X_smote, y_smote = smote.fit_resample(X, y)
y_smote
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 913    0
# 914    0
# 915    0
# 916    0
# 917    0
# Name: Target, Length: 918, dtype: int64

# %%
df_X_smote = pd.DataFrame(X_smote)
df_y_smote = pd.DataFrame(y_smote)
df_y_smote
# Out:
#      Target
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 913       0
# 914       0
# 915       0
# 916       0
# 917       0
#
# [918 rows x 1 columns]

# %% [markdown]
# # SVM Algoritm Model #

# %% [markdown]
# ## Dataset Split ##

# %% [markdown]
# Split the data to train and test

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm

X_train, X_test, y_train, y_test = train_test_split(df_X_smote, df_y_smote, test_size=0.33, random_state=42, stratify=y_smote)
svm_c2 = svm.SVC()
svm_c2.fit(X_train, y_train.values.ravel())
predictions = svm_c2.predict(X_test)

# %% [markdown]
# # Evaluation #

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import classification_report

score = round(accuracy_score(y_test, predictions), 2)
print("Accuracy score:", score)
print("SVM Classification report:" '\n', classification_report(y_test, predictions))
cm1 = cm(y_test, predictions)
sns.heatmap(cm1, annot=True, fmt=".0f")
print(plt.xlabel('Predicted Values'))
print(plt.ylabel('Actual Values'))
print(plt.title('Accuracy Score: {0}'.format(score), size=15))
print(plt.show())
# Out:
# Accuracy score: 0.87
# SVM Classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88       152
#            1       0.92      0.81      0.87       151
#
#     accuracy                           0.87       303
#    macro avg       0.88      0.87      0.87       303
# weighted avg       0.88      0.87      0.87       303
#
# Text(0.5, 15.0, 'Predicted Values')
# Text(33.0, 0.5, 'Actual Values')
# Text(0.5, 1.0, 'Accuracy Score: 0.87')
# None
